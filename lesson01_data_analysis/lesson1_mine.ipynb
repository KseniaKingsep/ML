# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/Ksenia/OneDrive/ML_HSE_BIG/HSE_BigML_AddProfEduc/HSE_BigML_AddProfEduc/module2_ML/data/telecom_churn.csv')

# %%
pd.read_csv?

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
type(data['State'])
# Out:
# pandas.core.series.Series

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
# State                     3333 non-null object
# Account length            3333 non-null int64
# Area code                 3333 non-null int64
# International plan        3333 non-null object
# Voice mail plan           3333 non-null object
# Number vmail messages     3333 non-null int64
# Total day minutes         3333 non-null float64
# Total day calls           3333 non-null int64
# Total day charge          3333 non-null float64
# Total eve minutes         3333 non-null float64
# Total eve calls           3333 non-null int64
# Total eve charge          3333 non-null float64
# Total night minutes       3333 non-null float64
# Total night calls         3333 non-null int64
# Total night charge        3333 non-null float64
# Total intl minutes        3333 non-null float64
# Total intl calls          3333 non-null int64
# Total intl charge         3333 non-null float64
# ...

# %%
data.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
data['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
data[data['International plan'] == 'Yes']['Churn'].value_counts()
# Out:
# False    186
# True     137
# Name: Churn, dtype: int64

# %%
#сводные таблицы
pd.crosstab(data['International plan'], data['Churn'])
# Out:
# Churn               False  True
# International plan
# No                   2664    346
# Yes                   186    137

# %%
data['State'].value_counts()
# Out:
# WV    106
# MN     84
# NY     83
# AL     80
# OH     78
# WI     78
# OR     78
# VA     77
# WY     77
# CT     74
# VT     73
# ID     73
# MI     73
# TX     72
# UT     72
# IN     71
# KS     70
# MD     70
# NJ     68
# NC     68
# MT     68
# CO     66
# WA     66
# NV     66
# MA     65
# RI     65
# MS     65
# AZ     64
# MO     63
# FL     63
# ND     62
# NM     62
# ME     62
# DE     61
# OK     61
# NE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# DC     54
# GA     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: State, dtype: int64

# %%
data[(data['State'] == 'NY') & (data['International plan'] == 'Yes')].shape
# Out:
# (8, 20)

# %%
data.shape
# Out:
# (3333, 20)

# %%
data.iloc[2,3]
# Out:
# 'No'

# %%
#по индексу
data.loc[2]
# Out:
# State                        NJ
# Account length              137
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes         243.4
# Total day calls             114
# Total day charge          41.38
# Total eve minutes         121.2
# Total eve calls             110
# Total eve charge           10.3
# Total night minutes       162.6
# Total night calls           104
# Total night charge         7.32
# Total intl minutes         12.2
# Total intl calls              5
# Total intl charge          3.29
# Customer service calls        0
# Churn                     False
# Name: 2, dtype: object

# %%
data['many_calls'] = data['Customer service calls'] > 4
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes    ...      Total eve charge  \
# 0             45.07              197.4    ...                 16.78
# ...

# %%
data['Total day calls'].describe()
# Out:
# count    3333.000000
# mean      100.435644
# std        20.069084
# min         0.000000
# 25%        87.000000
# 50%       101.000000
# 75%       114.000000
# max       165.000000
# Name: Total day calls, dtype: float64

# %%
#def many_talks(minutes):
#     return minutes > 100

# %%
# data['many_talks'] = data['Total day calls'].apply(many_talks)
data['many_talks'] = data['Total day calls'].apply(lambda x: x > 100)

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes    ...      Total night minutes  \
# 0             45.07              197.4    ...                    244.7
# ...

# %%
data['state_K'] = data['State'].apply(lambda x: x[0] == 'K')

# %%
data.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes   ...    Total night calls  \
# 0             45.07              197.4   ...                   91
# ...

# %%
data[data['state_K']].head()
# Out:
#     State  Account length  Area code International plan Voice mail plan  \
# 0      KS             128        415                 No             Yes
# 88     KY              74        415                 No             Yes
# 103    KY              95        408                 No              No
# 179    KS              70        408                 No              No
# 192    KY              80        408                 No              No
#
#      Number vmail messages  Total day minutes  Total day calls  \
# 0                       25              265.1              110
# 88                      35              154.1              104
# 103                      0              135.0               99
# 179                      0              232.1              122
# 192                      0              209.9               74
#
#      Total day charge  Total eve minutes   ...    Total night calls  \
# 0               45.07              197.4   ...                   91
# ...

# %%
for (plan, sub_df) in data.groupby('International plan'):
    print(plan)
    # print(sub_df.head(2))
    print(sub_df['Churn'].value_counts())
# Out:
# No
# False    2664
# True      346
# Name: Churn, dtype: int64
# Yes
# False    186
# True     137
# Name: Churn, dtype: int64

# %%
values = [[17,23,], [28,45], [60,61]]

# %%
df = pd.DataFrame(values, columns = ['age', 'wage'], index = ['John', 'Mary', 'Kate'])

# %%
df
# Out:
#       age  wage
# John   17    23
# Mary   28    45
# Kate   60    61

# %%
#нумерованный: номер строки, номер столбца
df.iloc[2,0]
# Out:
# 60

# %%
#поименно
df.loc['Mary', 'wage']
# Out:
# 45

# %%
df.loc[['John', 'Mary'], 'wage']
# Out:
# John    23
# Mary    45
# Name: wage, dtype: int64

# %%
#смесь
df.ix[['John', 'Mary'], 1]
# Out:
# John    23
# Mary    45
# Name: wage, dtype: int64

# %%
# %%time
df.ix[['John', 'Mary'], 1]
# Out:
# Wall time: 0 ns
# John    23
# Mary    45
# Name: wage, dtype: int64
